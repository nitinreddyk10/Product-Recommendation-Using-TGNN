# %% [markdown]
# # Exploring a Amazon data network in Memgraph
#
# Through this short tutorial, you will learn how to install Memgraph, connect to it from a Jupyter Notebook and perform data analysis on Amazon data set using **graph neural network** called **Temporal graph networks**.
# ## 1. Prerequisites
#
# For this tutorial, you will need to install:
#
# - [Jupyter](https://jupyter.org/install)
# - [Docker](https://docs.docker.com/get-docker/)
# - [GQLAlchemy](https://pypi.org/project/gqlalchemy/)
#
# Docker is used because Memgraph is a native Linux application and cannot be installed on Windows and macOS.

# %% [markdown]
# ## 2. Installation using Docker
#
# After installing Docker, you can set up Memgraph by running:
#
# ```
# docker run -it -p 7687:7687 -p 3000:3000 -p 7444:7444 memgraph/memgraph-platform
# ```
#
# This command will start the download and after it finishes, run the Memgraph container.

# %% [markdown]
# ## 3. Connecting to Memgraph with GQLAlchemy
#
# We will be using the **GQLAlchemy** object graph mapper (OGM) to connect to Memgraph and execute **Cypher** queries easily. GQLAlchemy also serves as a Python driver/client for Memgraph. You can install it using:
#
# ```
# pip install gqlalchemy
# ```
#
# > **Hint**: You may need to install [CMake](https://cmake.org/download/) before installing GQLAlchemy.
#
# Maybe you got confused when I mentioned Cypher. You can think of Cypher as SQL for graph databases. It contains many of the same language constructs like `CREATE`, `UPDATE`, `DELETE`... and it's used to query the database.

# %%
from gqlalchemy import Memgraph

# %%
memgraph = Memgraph("127.0.0.1", 7687)

# %% [markdown]
# Let's make sure that Memgraph is empty before we start with anything else.

# %%
memgraph.drop_database()

# %% [markdown]
# Following command should output {number_of_nodes:0}

# %%
results = memgraph.execute_and_fetch(
    """
    MATCH (n) RETURN count(n) AS number_of_nodes ;
    """
)
print(next(results))
# Out:
# {'number_of_nodes': 0}

# %% [markdown]
# ## 4. Data analysis on Amazon product dataset
#
# You will load an **amazon product dataset** as list of cypher queries. Here is how it looks:
# ![Dataset](images/amazon-user-item-dataset.png)
#
# One example of mentioned query is following one:
# ```cypher
# MERGE (a:User {id: 'A1BHUGKLYW6H7V', profile_name:'P. Lecuyer'})
# MERGE (b:Item {id: 'B0007MCVQ2'})
# MERGE (a)-[:REVIEWED {review_text:'Like all Clarks, these guys didnt disappoint. They fit great and look even better. For the price, I dont think a better deal exists out there for casual shoes.',
#   feature: [161.0, 133.0, 0.782608695652174, 0.0, 0.031055900621118012, 0.17391304347826086, 0.043478260869565216, 36.0, 36.0, 1.0, 3.6944444444444446, 0.0, 0.0, 3.0, 1.0, 12.0, 0.055, 0.519, 0.427, 0.9238],
#   review_time:1127088000, review_score:5.0}]->(b);
#
# ```
# So as you can see, we have `User` and we have `Item` in our graph sheme. Every user has left a very **positive** review for **Item**. This wasn't a case for all reviews in original dataset, but we processed it and removed negative reviews (all reviews with `review_score` <= 3.0).
# Every `User` as an `id` and every `Item` user has reviewed has also an `id`. In this one query, we find the `User` and the `Item` with mentioned ids or we create one if such `User` or `Item` is missing in database. And we create an interaction event between them in term of an `edge` which has list of **20** edge features. This `edge_features` we created from review user has left to an item:
#
# 1. Number of characters
# 2. Number of characters without counting white space
# 3. Fraction of alphabetical characters
# 4. Fraction of digits
# 5. Fraction of uppercase characters
# 6. Fraction of white spaces
# 7. Fraction of special characters, such as comma, exclamation mark, etc.
# 8. Number of words
# 9. Number of unique works
# 10. Number of long words (at least 6 characters)
# 11. Average word length
# 12. Number of unique stopwords
# 13. Fraction of stopwords
# 14. Number of sentences
# 15. Number of long sentences (at least 10 words)
# 16. Average number of words per sentence
# 17. Positive sentiment calculated by VADER
# 18. Negative sentiment calculated by VADER
# 19. Neutral sentiment calculated by VADER
# 20. Compound sentiment calculated by VADER
#
#
# We should have also prepared features for a `User`  and `Item`, but following features seemed enough for our **toy** example.

# %% [markdown]
# One more **note**: In those dataset of queries we already prepared for you, there is one query that will change "working mode" of our **temporal graph networks** module to **evaluation(eval)** mode. When mode is changed for **tgn** it also stops doing **training** of the model, and starts doing **evaluation** of trained model.
# If you look inside of file you should find following query:
#
# ```cypher
# CALL tgn.set_eval() YIELD *;
# ```

# %% [markdown]
# ### Trigger creation
# In order to process a dataset, we need to create trigger on **edge create** event if trigger with our name already doesn't exist.
#
# You will see, this check is a neat feature to have in your Jupyter notebook if you want just to rerun it without dumping **local Memgraph** instance if you are not working with **Docker**.

# %%
results = memgraph.execute_and_fetch("SHOW TRIGGERS;")

trigger_exists = False
for result in results:
    if result['trigger name'] == 'create_embeddings':
            print("Trigger already exists")
            trigger_exists = True
            break;
              

if not trigger_exists:
    memgraph.execute(
        """
        CREATE TRIGGER create_embeddings ON --> CREATE BEFORE COMMIT
        EXECUTE CALL tgn.update(createdEdges) RETURN 1;
        """
    )
# Out:
# Trigger already exists

# %% [markdown]
# ### Index creation for dataset

# %% [markdown]
# **Memgraph** works best with **indexes** defined for nodes, in our case we will have **User** and **Item** types.

# %%
index_queries = ["CREATE INDEX ON :User(id);",
                "CREATE INDEX ON :Item(id);"]

for query in index_queries:
    results = memgraph.execute_and_fetch(query)
    for result in results:
        continue

# %% [markdown]
# ### Training and evaluating Temporal Graph Networks

# %% [markdown]
# In order to train **Temporal graph networks** on **Amazon dataset** we will split dataset into **train** and **eval** queries. Let's first load our **raw queries**. Each query creates an **edge** between **User** and **Item**
# thus representing a **positive** review of a certain **Item** by a **User**.

# %%
import os

dir_path = os.getcwd()

with open(f"{dir_path}/data/queries.cypherl", "r") as fh:
    raw_queries = fh.readlines()

train_eval_split_ratio = 0.8
queries_index_split = int(len(raw_queries) * train_eval_split_ratio)

train_queries = raw_queries[:queries_index_split]
eval_queries = raw_queries[queries_index_split:]

print(f"Num of train queries {len(train_queries)}")
print(f"Num of eval queries {len(eval_queries)}")
# Out:
# Num of train queries 706
# Num of eval queries 177

# %% [markdown]
# Before we start importing **train** queries, first we need to set parameters for **temporal graph networks**.

# %%
# since we are doing link prediction, we use self_supervised mode
learning_type = "self_supervised"
batch_size = 200 #optimal size as defined in paper
num_of_layers = 2 # GNNs don't need multiple layers, contrary to CNNs.
layer_type = "graph_attn" # choose between graph_attn or graph_sum
edge_message_function_type = "identity" # choose between identity or mlp
message_aggregator_type = "last" # choose between last or mean
memory_updater_type = "gru" # choose between gru or rnn
attention_heads = 1
memory_dimension = 100
time_dimension = 100
num_edge_features = 20
num_node_features=100
# number of sampled neighbors
num_neighbors = 15
# message dimension must be defined in the case we use MLP, because then we define dimension of **projection**
message_dimension = time_dimension + num_node_features + num_edge_features

tgn_param_query = f"CALL tgn.set_params({{learning_type:'{learning_type}', batch_size: {batch_size}, num_of_layers:{num_of_layers}, layer_type:'{layer_type}', memory_dimension:{memory_dimension}, time_dimension:{time_dimension}, num_edge_features:{num_edge_features}, num_node_features:{num_node_features}, message_dimension:{message_dimension}, num_neighbors:{num_neighbors}, edge_message_function_type:'{edge_message_function_type}', message_aggregator_type:'{message_aggregator_type}', memory_updater_type:'{memory_updater_type}', attention_heads:{attention_heads}}}) YIELD *;"

print(f"TGN param query: {tgn_param_query}")

results = memgraph.execute_and_fetch(tgn_param_query)
for result in results:
    print(result)
# Out:
# TGN param query: CALL tgn.set_params({learning_type:'self_supervised', batch_size: 200, num_of_layers:2, layer_type:'graph_attn', memory_dimension:100, time_dimension:100, num_edge_features:20, num_node_features:100, message_dimension:220, num_neighbors:15, edge_message_function_type:'identity', message_aggregator_type:'last', memory_updater_type:'gru', attention_heads:1}) YIELD *;

# %% [markdown]
# Now it is time to execute queries and do **first** epoch of **training**.

# %%
for i, query in enumerate(train_queries):
    print(f"Executing query {i}: {query}")
    results = memgraph.execute_and_fetch(query.strip())
    for result in results:
        continue
# Out:
# Executing query 0: MATCH (n) DETACH DELETE n;
#
# Executing query 1: MERGE (a:User {id: ' A1BHUGKLYW6H7V', profile_name:' P. Lecuyer'}) MERGE (b:Item {id: ' B0007MCVQ2'}) MERGE (a)-[:REVIEWED {review_text:' P. Lecuyer', feature: [162.0, 133.0, 0.7777777777777778, 0.0, 0.030864197530864196, 0.17901234567901234, 0.043209876543209874, 37.0, 37.0, 1.0, 3.6216216216216215, 0.0, 0.0, 3.0, 2.0, 12.333333333333334, 0.055, 0.519, 0.427, 0.9238], review_time:1127088000, review_score:5.0}]->(b);
#
# Executing query 2: MERGE (a:User {id: ' AITX28WR0L5Y6', profile_name:' Carol Popick Chet'}) MERGE (b:Item {id: ' B0002M1FPK'}) MERGE (a)-[:REVIEWED {review_text:' Carol Popick Chet', feature: [230.0, 184.0, 0.782608695652174, 0.0, 0.7782608695652173, 0.2, 0.017391304347826087, 51.0, 51.0, 3.0, 3.627450980392157, 0.0, 0.0, 4.0, 3.0, 12.75, 0.0, 0.798, 0.202, 0.8553], review_time:1245715200, review_score:5.0}]->(b);
#
# Executing query 3: MERGE (a:User {id: ' A1ZPFKIGT4I69S', profile_name:' KJ Brassy KJ Brassy'}) MERGE (b:Item {id: ' B0002M1FPK'}) MERGE (a)-[:REVIEWED {review_text:' KJ Brassy KJ Brassy', feature: [332.0, 268.0, 0.7740963855421686, 0.0030120481927710845, 0.024096385542168676, 0.1927710843373494, 0.030120481927710843, 75.0, 75.0, 7.0, 3.5866666666666664, 0.0, 0.0, 6.0, 4.0, 12.5, 0.03, 0.699, 0.271, 0.9556], review_time:1168300800, review_score:5.0}]->(b);
#
# Executing query 4: MERGE (a:User {id: ' A1V0A67G2G1LLD', profile_name:' Benita Zepeda'}) MERGE (b:Item {id: ' B0002M1FPK'}) MERGE (a)-[:REVIEWED {review_text:' Benita Zepeda', feature: [133.0, 110.0, 0.8120300751879699, 0.0, 0.0, 0.17293233082706766, 0.015037593984962405, 25.0, 25.0, 5.0, 4.44, 0.0, 0.0, 1.0, 1.0, 25.0, 0.0, 0.735, 0.265, 0.8016], review_time:1154390400, review_score:5.0}]->(b);
#
# Executing query 5: MERGE (a:User {id: ' AAKXVKU3NYUA2', profile_name:' Serious Shopper Smilin'}) MERGE (b:Item {id: ' B000F74YLY'}) MERGE (a)-[:REVIEWED {review_text:' Serious Shopper Smilin', feature: [200.0, 160.0, 0.77, 0.0, 0.01, 0.2, 0.03, 46.0, 46.0, 2.0, 3.5, 0.0, 0.0, 4.0, 2.0, 11.5, 0.0, 0.743, 0.257, 0.9017], review_time:1240617600, review_score:5.0}]->(b);
#
# Executing query 6: MERGE (a:User {id: ' A7WYOWW6MUAOC', profile_name:' Lily Wong'}) MERGE (b:Item {id: ' B0006HA17E'}) MERGE (a)-[:REVIEWED {review_text:' Lily Wong', feature: [185.0, 150.0, 0.772972972972973, 0.0, 0.021621621621621623, 0.1891891891891892, 0.03783783783783784, 41.0, 41.0, 2.0, 3.682926829268293, 0.0, 0.0, 3.0, 2.0, 13.666666666666666, 0.0, 0.698, 0.302, 0.9111], review_time:1172880000, review_score:5.0}]->(b);
#
# Executing query 7: MERGE (a:User {id: ' A2TAXQQW95KBWC', profile_name:' Susan D. Andersen'}) MERGE (b:Item {id: ' B0006HA17E'}) MERGE (a)-[:REVIEWED {review_text:' Susan D. Andersen', feature: [75.0, 61.0, 0.7733333333333333, 0.0, 0.0, 0.18666666666666668, 0.04, 18.0, 18.0, 1.0, 3.4444444444444446, 0.0, 0.0, 3.0, 0.0, 6.0, 0.0, 0.625, 0.375, 0.8016], review_time:1179187200, review_score:5.0}]->(b);
#
# Executing query 8: MERGE (a:User {id: ' AITX28WR0L5Y6', profile_name:' Carol Popick Chet'}) MERGE (b:Item {id: ' B0002M1FQ4'}) MERGE (a)-[:REVIEWED {review_text:' Carol Popick Chet', feature: [230.0, 184.0, 0.782608695652174, 0.0, 0.7782608695652173, 0.2, 0.017391304347826087, 51.0, 51.0, 3.0, 3.627450980392157, 0.0, 0.0, 4.0, 3.0, 12.75, 0.0, 0.798, 0.202, 0.8553], review_time:1245715200, review_score:5.0}]->(b);
#
# Executing query 9: MERGE (a:User {id: ' A1ZPFKIGT4I69S', profile_name:' KJ Brassy KJ Brassy'}) MERGE (b:Item {id: ' B0002M1FQ4'}) MERGE (a)-[:REVIEWED {review_text:' KJ Brassy KJ Brassy', feature: [332.0, 268.0, 0.7740963855421686, 0.0030120481927710845, 0.024096385542168676, 0.1927710843373494, 0.030120481927710843, 75.0, 75.0, 7.0, 3.5866666666666664, 0.0, 0.0, 6.0, 4.0, 12.5, 0.03, 0.699, 0.271, 0.9556], review_time:1168300800, review_score:5.0}]->(b);
#
# Executing query 10: MERGE (a:User {id: ' A1V0A67G2G1LLD', profile_name:' Benita Zepeda'}) MERGE (b:Item {id: ' B0002M1FQ4'}) MERGE (a)-[:REVIEWED {review_text:' Benita Zepeda', feature: [133.0, 110.0, 0.8120300751879699, 0.0, 0.0, 0.17293233082706766, 0.015037593984962405, 25.0, 25.0, 5.0, 4.44, 0.0, 0.0, 1.0, 1.0, 25.0, 0.0, 0.735, 0.265, 0.8016], review_time:1154390400, review_score:5.0}]->(b);
#
# Executing query 11: MERGE (a:User {id: ' A1A900LBDV9EOZ', profile_name:' Melanies Review'}) MERGE (b:Item {id: ' B000MPRIXA'}) MERGE (a)-[:REVIEWED {review_text:' Melanies Review', feature: [330.0, 266.0, 0.7787878787878788, 0.0030303030303030303, 0.02727272727272727, 0.19393939393939394, 0.024242424242424242, 74.0, 74.0, 4.0, 3.608108108108108, 0.0, 0.0, 5.0, 3.0, 14.8, 0.0, 0.746, 0.254, 0.9586], review_time:1176163200, review_score:5.0}]->(b);
#
# Executing query 12: MERGE (a:User {id: ' AITX28WR0L5Y6', profile_name:' Carol Popick Chet'}) MERGE (b:Item {id: ' B0002M1FRS'}) MERGE (a)-[:REVIEWED {review_text:' Carol Popick Chet', feature: [230.0, 184.0, 0.782608695652174, 0.0, 0.7782608695652173, 0.2, 0.017391304347826087, 51.0, 51.0, 3.0, 3.627450980392157, 0.0, 0.0, 4.0, 3.0, 12.75, 0.0, 0.798, 0.202, 0.8553], review_time:1245715200, review_score:5.0}]->(b);
#
# Executing query 13: MERGE (a:User {id: ' A1ZPFKIGT4I69S', profile_name:' KJ Brassy KJ Brassy'}) MERGE (b:Item {id: ' B0002M1FRS'}) MERGE (a)-[:REVIEWED {review_text:' KJ Brassy KJ Brassy', feature: [332.0, 268.0, 0.7740963855421686, 0.0030120481927710845, 0.024096385542168676, 0.1927710843373494, 0.030120481927710843, 75.0, 75.0, 7.0, 3.5866666666666664, 0.0, 0.0, 6.0, 4.0, 12.5, 0.03, 0.699, 0.271, 0.9556], review_time:1168300800, review_score:5.0}]->(b);
#
# Executing query 14: MERGE (a:User {id: ' A1V0A67G2G1LLD', profile_name:' Benita Zepeda'}) MERGE (b:Item {id: ' B0002M1FRS'}) MERGE (a)-[:REVIEWED {review_text:' Benita Zepeda', feature: [133.0, 110.0, 0.8120300751879699, 0.0, 0.0, 0.17293233082706766, 0.015037593984962405, 25.0, 25.0, 5.0, 4.44, 0.0, 0.0, 1.0, 1.0, 25.0, 0.0, 0.735, 0.265, 0.8016], review_time:1154390400, review_score:5.0}]->(b);
#
# Executing query 15: MERGE (a:User {id: ' A218Z9ZAFGUZ46', profile_name:' clarissa'}) MERGE (b:Item {id: ' B000OASQLG'}) MERGE (a)-[:REVIEWED {review_text:' clarissa', feature: [98.0, 81.0, 0.7959183673469388, 0.0, 0.01020408163265306, 0.17346938775510204, 0.030612244897959183, 21.0, 21.0, 4.0, 3.9047619047619047, 0.0, 0.0, 2.0, 1.0, 10.5, 0.0, 0.596, 0.404, 0.8591], review_time:1179014400, review_score:5.0}]->(b);
#
# Executing query 16: MERGE (a:User {id: ' A1PU5LM0AUYPCM', profile_name:' Jude Jude'}) MERGE (b:Item {id: ' B000OASQLG'}) MERGE (a)-[:REVIEWED {review_text:' Jude Jude', feature: [977.0, 786.0, 0.7717502558853634, 0.0020470829068577278, 0.019447287615148412, 0.195496417604913, 0.030706243602865915, 221.0, 221.0, 22.0, 3.5610859728506785, 0.0, 0.0, 12.0, 10.0, 18.416666666666668, 0.025, 0.747, 0.228, 0.9916], review_time:1222732800, review_score:5.0}]->(b);
#
# Executing query 17: MERGE (a:User {id: ' A3PLLZPUG4XRTS', profile_name:' Adele M. Smith ADELE'}) MERGE (b:Item {id: ' B000OASQLG'}) MERGE (a)-[:REVIEWED {review_text:' Adele M. Smith ADELE', feature: [177.0, 148.0, 0.7909604519774012, 0.0, 0.01694915254237288, 0.1638418079096045, 0.04519774011299435, 37.0, 37.0, 6.0, 4.027027027027027, 0.0, 0.0, 3.0, 2.0, 12.333333333333334, 0.0, 0.532, 0.468, 0.9552], review_time:1189036800, review_score:5.0}]->(b);
#
# Executing query 18: MERGE (a:User {id: ' AITX28WR0L5Y6', profile_name:' Carol Popick Chet'}) MERGE (b:Item {id: ' B0002M1FR8'}) MERGE (a)-[:REVIEWED {review_text:' Carol Popick Chet', feature: [230.0, 184.0, 0.782608695652174, 0.0, 0.7782608695652173, 0.2, 0.017391304347826087, 51.0, 51.0, 3.0, 3.627450980392157, 0.0, 0.0, 4.0, 3.0, 12.75, 0.0, 0.798, 0.202, 0.8553], review_time:1245715200, review_score:5.0}]->(b);
#
# Executing query 19: MERGE (a:User {id: ' A1ZPFKIGT4I69S', profile_name:' KJ Brassy KJ Brassy'}) MERGE (b:Item {id: ' B0002M1FR8'}) MERGE (a)-[:REVIEWED {review_text:' KJ Brassy KJ Brassy', feature: [332.0, 268.0, 0.7740963855421686, 0.0030120481927710845, 0.024096385542168676, 0.1927710843373494, 0.030120481927710843, 75.0, 75.0, 7.0, 3.5866666666666664, 0.0, 0.0, 6.0, 4.0, 12.5, 0.03, 0.699, 0.271, 0.9556], review_time:1168300800, review_score:5.0}]->(b);
#
# Executing query 20: MERGE (a:User {id: ' A1V0A67G2G1LLD', profile_name:' Benita Zepeda'}) MERGE (b:Item {id: ' B0002M1FR8'}) MERGE (a)-[:REVIEWED {review_text:' Benita Zepeda', feature: [133.0, 110.0, 0.8120300751879699, 0.0, 0.0, 0.17293233082706766, 0.015037593984962405, 25.0, 25.0, 5.0, 4.44, 0.0, 0.0, 1.0, 1.0, 25.0, 0.0, 0.735, 0.265, 0.8016], review_time:1154390400, review_score:5.0}]->(b);
#
# Executing query 21: MERGE (a:User {id: ' A2XSP2UGJ360UP', profile_name:' B. Wong B-dub'}) MERGE (b:Item {id: ' B000PEQ7SA'}) MERGE (a)-[:REVIEWED {review_text:' B. Wong B-dub', feature: [171.0, 136.0, 0.7602339181286549, 0.0, 0.023391812865497075, 0.2046783625730994, 0.03508771929824561, 42.0, 42.0, 2.0, 3.261904761904762, 0.0, 0.0, 3.0, 2.0, 14.0, 0.071, 0.811, 0.118, 0.2144], review_time:1261267200, review_score:5.0}]->(b);
#
# Executing query 22: MERGE (a:User {id: ' ABH1UKSISSW69', profile_name:' Sarah Grace'}) MERGE (b:Item {id: ' B000PEQ7SA'}) MERGE (a)-[:REVIEWED {review_text:' Sarah Grace', feature: [336.0, 279.0, 0.8035714285714286, 0.0, 0.026785714285714284, 0.16964285714285715, 0.026785714285714284, 67.0, 67.0, 12.0, 4.17910447761194, 0.0, 0.0, 4.0, 3.0, 16.75, 0.025, 0.751, 0.224, 0.8654], review_time:1228262400, review_score:5.0}]->(b);
#
# Executing query 23: MERGE (a:User {id: ' A3HH6ALT3RQCXX', profile_name:' Shuai Li'}) MERGE (b:Item {id: ' B000O3QCKU'}) MERGE (a)-[:REVIEWED {review_text:' Shuai Li', feature: [1180.0, 970.0, 0.785593220338983, 0.0, 0.02288135593220339, 0.17796610169491525, 0.036440677966101696, 260.0, 260.0, 39.0, 3.7346153846153847, 0.0, 0.0, 15.0, 10.0, 17.333333333333332, 0.025, 0.743, 0.231, 0.9955], review_time:1190332800, review_score:5.0}]->(b);
#
# Executing query 24: MERGE (a:User {id: ' A14260SU8PYXGU', profile_name:' Jeff Wang beatakai'}) MERGE (b:Item {id: ' B000O3QCKU'}) MERGE (a)-[:REVIEWED {review_text:' Jeff Wang beatakai', feature: [257.0, 208.0, 0.7704280155642024, 0.0038910505836575876, 0.0038910505836575876, 0.19066147859922178, 0.03501945525291829, 59.0, 59.0, 5.0, 3.542372881355932, 0.0, 0.0, 5.0, 3.0, 11.8, 0.0, 0.733, 0.267, 0.9359], review_time:1189296000, review_score:5.0}]->(b);
#
# Executing query 25: MERGE (a:User {id: ' AITX28WR0L5Y6', profile_name:' Carol Popick Chet'}) MERGE (b:Item {id: ' B0002M1FSW'}) MERGE (a)-[:REVIEWED {review_text:' Carol Popick Chet', feature: [230.0, 184.0, 0.782608695652174, 0.0, 0.7782608695652173, 0.2, 0.017391304347826087, 51.0, 51.0, 3.0, 3.627450980392157, 0.0, 0.0, 4.0, 3.0, 12.75, 0.0, 0.798, 0.202, 0.8553], review_time:1245715200, review_score:5.0}]->(b);
#
# Executing query 26: MERGE (a:User {id: ' A1ZPFKIGT4I69S', profile_name:' KJ Brassy KJ Brassy'}) MERGE (b:Item {id: ' B0002M1FSW'}) MERGE (a)-[:REVIEWED {review_text:' KJ Brassy KJ Brassy', feature: [332.0, 268.0, 0.7740963855421686, 0.0030120481927710845, 0.024096385542168676, 0.1927710843373494, 0.030120481927710843, 75.0, 75.0, 7.0, 3.5866666666666664, 0.0, 0.0, 6.0, 4.0, 12.5, 0.03, 0.699, 0.271, 0.9556], review_time:1168300800, review_score:5.0}]->(b);
#
# Executing query 27: MERGE (a:User {id: ' A1V0A67G2G1LLD', profile_name:' Benita Zepeda'}) MERGE (b:Item {id: ' B0002M1FSW'}) MERGE (a)-[:REVIEWED {review_text:' Benita Zepeda', feature: [133.0, 110.0, 0.8120300751879699, 0.0, 0.0, 0.17293233082706766, 0.015037593984962405, 25.0, 25.0, 5.0, 4.44, 0.0, 0.0, 1.0, 1.0, 25.0, 0.0, 0.735, 0.265, 0.8016], review_time:1154390400, review_score:5.0}]->(b);
#
# Executing query 28: MERGE (a:User {id: ' AITX28WR0L5Y6', profile_name:' Carol Popick Chet'}) MERGE (b:Item {id: ' B0002M1FSC'}) MERGE (a)-[:REVIEWED {review_text:' Carol Popick Chet', feature: [230.0, 184.0, 0.782608695652174, 0.0, 0.7782608695652173, 0.2, 0.017391304347826087, 51.0, 51.0, 3.0, 3.627450980392157, 0.0, 0.0, 4.0, 3.0, 12.75, 0.0, 0.798, 0.202, 0.8553], review_time:1245715200, review_score:5.0}]->(b);
#
# Executing query 29: MERGE (a:User {id: ' A1ZPFKIGT4I69S', profile_name:' KJ Brassy KJ Brassy'}) MERGE (b:Item {id: ' B0002M1FSC'}) MERGE (a)-[:REVIEWED {review_text:' KJ Brassy KJ Brassy', feature: [332.0, 268.0, 0.7740963855421686, 0.0030120481927710845, 0.024096385542168676, 0.1927710843373494, 0.030120481927710843, 75.0, 75.0, 7.0, 3.5866666666666664, 0.0, 0.0, 6.0, 4.0, 12.5, 0.03, 0.699, 0.271, 0.9556], review_time:1168300800, review_score:5.0}]->(b);
#
# Executing query 30: MERGE (a:User {id: ' A1V0A67G2G1LLD', profile_name:' Benita Zepeda'}) MERGE (b:Item {id: ' B0002M1FSC'}) MERGE (a)-[:REVIEWED {review_text:' Benita Zepeda', feature: [133.0, 110.0, 0.8120300751879699, 0.0, 0.0, 0.17293233082706766, 0.015037593984962405, 25.0, 25.0, 5.0, 4.44, 0.0, 0.0, 1.0, 1.0, 25.0, 0.0, 0.735, 0.265, 0.8016], review_time:1154390400, review_score:5.0}]->(b);
#
# Executing query 31: MERGE (a:User {id: ' A1N82BBPB5816P', profile_name:' J. Barrera'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' J. Barrera', feature: [348.0, 277.0, 0.7586206896551724, 0.017241379310344827, 0.031609195402298854, 0.20402298850574713, 0.020114942528735632, 80.0, 80.0, 6.0, 3.475, 0.0, 0.0, 4.0, 4.0, 20.0, 0.068, 0.861, 0.071, 0.0498], review_time:1324857600, review_score:5.0}]->(b);
#
# Executing query 32: MERGE (a:User {id: ' A2U6L2E1AFW26V', profile_name:' zmack9598'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' zmack9598', feature: [199.0, 162.0, 0.7839195979899497, 0.0, 0.05527638190954774, 0.18592964824120603, 0.03015075376884422, 45.0, 45.0, 4.0, 3.6222222222222222, 0.0, 0.0, 4.0, 3.0, 11.25, 0.0, 0.749, 0.251, 0.886], review_time:1324425600, review_score:5.0}]->(b);
#
# Executing query 33: MERGE (a:User {id: ' A3P7M6FZMXJP', profile_name:' Michael Cody'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Michael Cody', feature: [247.0, 201.0, 0.7530364372469636, 0.016194331983805668, 0.024291497975708502, 0.1862348178137652, 0.044534412955465584, 56.0, 56.0, 5.0, 3.607142857142857, 0.0, 0.0, 4.0, 2.0, 14.0, 0.029, 0.772, 0.199, 0.8807], review_time:1323734400, review_score:5.0}]->(b);
#
# Executing query 34: MERGE (a:User {id: ' A1EIQ8GPC85N4D', profile_name:' msmorality'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' msmorality', feature: [260.0, 217.0, 0.8, 0.011538461538461539, 0.015384615384615385, 0.16538461538461538, 0.023076923076923078, 50.0, 50.0, 10.0, 4.36, 0.0, 0.0, 5.0, 2.0, 10.0, 0.0, 0.672, 0.328, 0.9391], review_time:1323734400, review_score:5.0}]->(b);
#
# Executing query 35: MERGE (a:User {id: ' A1LNWOCCGMYHF3', profile_name:' R. Jackson'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' R. Jackson', feature: [442.0, 356.0, 0.7714932126696833, 0.013574660633484163, 0.02262443438914027, 0.19457013574660634, 0.020361990950226245, 97.0, 97.0, 12.0, 3.6804123711340204, 0.0, 0.0, 4.0, 4.0, 24.25, 0.0, 0.904, 0.096, 0.8507], review_time:1323388800, review_score:5.0}]->(b);
#
# Executing query 36: MERGE (a:User {id: ' A2T014NNWWZNTP', profile_name:' P. Daly'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' P. Daly', feature: [720.0, 575.0, 0.7763888888888889, 0.001388888888888889, 0.020833333333333332, 0.2013888888888889, 0.020833333333333332, 163.0, 163.0, 9.0, 3.5337423312883436, 0.0, 0.0, 5.0, 5.0, 32.6, 0.045, 0.824, 0.132, 0.9329], review_time:1323388800, review_score:5.0}]->(b);
#
# Executing query 37: MERGE (a:User {id: ' A197AJG3D6ZVWK', profile_name:' Taimur D Jah'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Taimur D Jah', feature: [420.0, 348.0, 0.8071428571428572, 0.0, 0.02619047619047619, 0.17142857142857143, 0.02142857142857143, 84.0, 84.0, 14.0, 4.154761904761905, 0.0, 0.0, 6.0, 4.0, 14.0, 0.028, 0.808, 0.164, 0.891], review_time:1322784000, review_score:5.0}]->(b);
#
# Executing query 38: MERGE (a:User {id: ' A345EFAB1ZWCL2', profile_name:' Brian the Wanderer'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Brian the Wanderer', feature: [724.0, 583.0, 0.7665745856353591, 0.0055248618784530384, 0.029005524861878452, 0.19475138121546962, 0.03314917127071823, 167.0, 167.0, 14.0, 3.497005988023952, 0.0, 0.0, 10.0, 8.0, 16.7, 0.046, 0.763, 0.191, 0.9519], review_time:1293840000, review_score:5.0}]->(b);
#
# Executing query 39: MERGE (a:User {id: ' A1QD4XO09R1CRD', profile_name:' Ron'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Ron', feature: [261.0, 213.0, 0.7816091954022989, 0.0, 0.04980842911877394, 0.1839080459770115, 0.034482758620689655, 61.0, 61.0, 8.0, 3.5081967213114753, 0.0, 0.0, 4.0, 3.0, 15.25, 0.0, 0.859, 0.141, 0.7845], review_time:1293753600, review_score:5.0}]->(b);
#
# Executing query 40: MERGE (a:User {id: ' A28ZQLQLUC8RVG', profile_name:' Jimmy T marylandmx'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Jimmy T marylandmx', feature: [123.0, 99.0, 0.7804878048780488, 0.008130081300813009, 0.032520325203252036, 0.1951219512195122, 0.016260162601626018, 28.0, 28.0, 4.0, 3.5714285714285716, 0.0, 0.0, 1.0, 1.0, 28.0, 0.0, 0.742, 0.258, 0.765], review_time:1292544000, review_score:5.0}]->(b);
#
# Executing query 41: MERGE (a:User {id: ' A2GLF5VKC6B9JF', profile_name:' Velma Limmeroth'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Velma Limmeroth', feature: [477.0, 387.0, 0.7672955974842768, 0.0020964360587002098, 0.031446540880503145, 0.18867924528301888, 0.041928721174004195, 109.0, 109.0, 10.0, 3.5596330275229358, 0.0, 0.0, 9.0, 6.0, 12.11111111111111, 0.0, 0.798, 0.202, 0.964], review_time:1292284800, review_score:5.0}]->(b);
#
# Executing query 42: MERGE (a:User {id: ' A1KHSNJBY5JAHY', profile_name:' onin24eagle'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' onin24eagle', feature: [480.0, 386.0, 0.7833333333333333, 0.0, 0.03958333333333333, 0.19583333333333333, 0.020833333333333332, 105.0, 105.0, 8.0, 3.6857142857142855, 0.0, 0.0, 9.0, 5.0, 11.666666666666666, 0.064, 0.791, 0.146, 0.734], review_time:1291248000, review_score:5.0}]->(b);
#
# Executing query 43: MERGE (a:User {id: ' A1YUZKMB9PTGMN', profile_name:' bargain shopper'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' bargain shopper', feature: [234.0, 190.0, 0.7863247863247863, 0.004273504273504274, 0.017094017094017096, 0.18803418803418803, 0.021367521367521368, 54.0, 54.0, 3.0, 3.537037037037037, 0.0, 0.0, 4.0, 3.0, 13.5, 0.0, 0.613, 0.387, 0.9628], review_time:1290297600, review_score:5.0}]->(b);
#
# Executing query 44: MERGE (a:User {id: ' AFI6X549RWXQ4', profile_name:' dirtcurt'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' dirtcurt', feature: [846.0, 685.0, 0.7813238770685579, 0.004728132387706856, 0.03546099290780142, 0.19030732860520094, 0.02364066193853428, 180.0, 180.0, 24.0, 3.811111111111111, 0.0, 0.0, 14.0, 8.0, 12.857142857142858, 0.011, 0.776, 0.214, 0.9878], review_time:1289433600, review_score:5.0}]->(b);
#
# Executing query 45: MERGE (a:User {id: ' A1GQZHT7223HUJ', profile_name:' Tom C. TC'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Tom C. TC', feature: [271.0, 220.0, 0.7675276752767528, 0.0, 0.03690036900369004, 0.1881918819188192, 0.04428044280442804, 63.0, 63.0, 4.0, 3.507936507936508, 0.0, 0.0, 5.0, 4.0, 12.6, 0.04, 0.725, 0.235, 0.8953], review_time:1234742400, review_score:5.0}]->(b);
#
# Executing query 46: MERGE (a:User {id: ' AO57JFIV2M7HN', profile_name:' Kat Fyten Katseye'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Kat Fyten Katseye', feature: [158.0, 127.0, 0.7848101265822784, 0.0, 0.0189873417721519, 0.1962025316455696, 0.0189873417721519, 35.0, 35.0, 4.0, 3.657142857142857, 0.0, 0.0, 2.0, 2.0, 17.5, 0.0, 0.915, 0.085, 0.4168], review_time:1231632000, review_score:5.0}]->(b);
#
# Executing query 47: MERGE (a:User {id: ' A2TX64KU8YJV59', profile_name:' RB'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' RB', feature: [790.0, 638.0, 0.7835443037974683, 0.006329113924050633, 0.027848101265822784, 0.19240506329113924, 0.017721518987341773, 168.0, 168.0, 21.0, 3.8035714285714284, 0.0, 0.0, 9.0, 6.0, 18.666666666666668, 0.064, 0.757, 0.18, 0.9648], review_time:1307923200, review_score:5.0}]->(b);
#
# Executing query 48: MERGE (a:User {id: ' A849OPW1VIRVW', profile_name:' Charles E. Wewer CHARLIE W.'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Charles E. Wewer CHARLIE W.', feature: [276.0, 227.0, 0.7717391304347826, 0.0, 0.7717391304347826, 0.17753623188405798, 0.050724637681159424, 63.0, 63.0, 9.0, 3.619047619047619, 0.0, 0.0, 6.0, 3.0, 10.5, 0.042, 0.849, 0.108, 0.5267], review_time:1234656000, review_score:5.0}]->(b);
#
# Executing query 49: MERGE (a:User {id: ' AKCB425IHCLQD', profile_name:' Martin Lisius'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Martin Lisius', feature: [385.0, 318.0, 0.8025974025974026, 0.0, 0.05454545454545454, 0.17402597402597403, 0.023376623376623377, 80.0, 80.0, 10.0, 3.9875, 0.0, 0.0, 6.0, 4.0, 13.333333333333334, 0.064, 0.755, 0.181, 0.882], review_time:1186358400, review_score:5.0}]->(b);
#
# Executing query 50: MERGE (a:User {id: ' A2W60XQGJWP2QL', profile_name:' A. L. Trail Jet-Tech'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' A. L. Trail Jet-Tech', feature: [363.0, 291.0, 0.768595041322314, 0.0, 0.02203856749311295, 0.19834710743801653, 0.03305785123966942, 85.0, 85.0, 5.0, 3.4352941176470586, 0.0, 0.0, 6.0, 4.0, 14.166666666666666, 0.103, 0.722, 0.175, 0.7669], review_time:1223251200, review_score:5.0}]->(b);
#
# Executing query 51: MERGE (a:User {id: ' AX2QUY0O7KVHK', profile_name:' masshole dynomyte'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' masshole dynomyte', feature: [368.0, 296.0, 0.7853260869565217, 0.0, 0.019021739130434784, 0.1956521739130435, 0.019021739130434784, 80.0, 80.0, 5.0, 3.7125, 0.0, 0.0, 4.0, 4.0, 20.0, 0.068, 0.831, 0.101, 0.3612], review_time:1199318400, review_score:5.0}]->(b);
#
# Executing query 52: MERGE (a:User {id: ' AU9CGETPMJY6K', profile_name:' Toerau'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Toerau', feature: [187.0, 152.0, 0.7540106951871658, 0.0, 0.053475935828877004, 0.18716577540106952, 0.058823529411764705, 44.0, 44.0, 7.0, 3.477272727272727, 0.0, 0.0, 2.0, 2.0, 22.0, 0.0, 0.668, 0.332, 0.899], review_time:1349481600, review_score:5.0}]->(b);
#
# Executing query 53: MERGE (a:User {id: ' A2S31JZNVP68DF', profile_name:' tenderfoot'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' tenderfoot', feature: [607.0, 488.0, 0.7808896210873146, 0.0, 0.07248764415156507, 0.19604612850082373, 0.023064250411861616, 130.0, 130.0, 7.0, 3.7615384615384615, 0.0, 0.0, 10.0, 6.0, 13.0, 0.028, 0.797, 0.175, 0.9698], review_time:1347321600, review_score:5.0}]->(b);
#
# Executing query 54: MERGE (a:User {id: ' A2WWL6ULY51UBU', profile_name:' Dangerous Dirk $'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Dangerous Dirk $', feature: [245.0, 200.0, 0.7714285714285715, 0.0, 0.0163265306122449, 0.1836734693877551, 0.044897959183673466, 58.0, 58.0, 5.0, 3.4655172413793105, 0.0, 0.0, 3.0, 3.0, 19.333333333333332, 0.0, 0.729, 0.271, 0.9343], review_time:1346544000, review_score:5.0}]->(b);
#
# Executing query 55: MERGE (a:User {id: ' A2COO4ZJ4E54MO', profile_name:' Christie'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Christie', feature: [407.0, 328.0, 0.769041769041769, 0.002457002457002457, 0.02702702702702703, 0.1941031941031941, 0.0343980343980344, 94.0, 94.0, 7.0, 3.5, 0.0, 0.0, 7.0, 3.0, 13.428571428571429, 0.022, 0.897, 0.081, 0.6837], review_time:1344729600, review_score:5.0}]->(b);
#
# Executing query 56: MERGE (a:User {id: ' A2QAN27NWI581E', profile_name:' Margaret J. Lynne'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Margaret J. Lynne', feature: [159.0, 130.0, 0.7987421383647799, 0.0, 0.018867924528301886, 0.18238993710691823, 0.018867924528301886, 33.0, 33.0, 4.0, 3.9696969696969697, 0.0, 0.0, 2.0, 2.0, 16.5, 0.0, 0.55, 0.45, 0.9582], review_time:1344643200, review_score:5.0}]->(b);
#
# Executing query 57: MERGE (a:User {id: ' AMFW6E3XNQ66J', profile_name:' William A. Eggers'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' William A. Eggers', feature: [378.0, 315.0, 0.8068783068783069, 0.0, 0.023809523809523808, 0.16666666666666666, 0.026455026455026454, 76.0, 76.0, 14.0, 4.157894736842105, 0.0, 0.0, 5.0, 4.0, 15.2, 0.0, 0.861, 0.139, 0.8658], review_time:1344470400, review_score:5.0}]->(b);
#
# Executing query 58: MERGE (a:User {id: ' APBI2P3XVZI42', profile_name:' Pang Zi Yang'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Pang Zi Yang', feature: [126.0, 103.0, 0.7936507936507936, 0.0, 0.03968253968253968, 0.18253968253968253, 0.023809523809523808, 27.0, 27.0, 3.0, 3.8518518518518516, 0.0, 0.0, 4.0, 0.0, 6.75, 0.0, 0.775, 0.225, 0.5859], review_time:1357862400, review_score:5.0}]->(b);
#
# Executing query 59: MERGE (a:User {id: ' A33YZNZIRA3H97', profile_name:' l2'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' l2', feature: [544.0, 448.0, 0.7886029411764706, 0.003676470588235294, 0.016544117647058824, 0.17647058823529413, 0.03125, 118.0, 118.0, 13.0, 3.805084745762712, 0.0, 0.0, 6.0, 6.0, 19.666666666666668, 0.0, 0.801, 0.199, 0.9694], review_time:1357862400, review_score:5.0}]->(b);
#
# Executing query 60: MERGE (a:User {id: ' A2JL6DOLHBPV2A', profile_name:' Bob Brewer'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Bob Brewer', feature: [141.0, 114.0, 0.7872340425531915, 0.0, 0.02127659574468085, 0.19148936170212766, 0.02127659574468085, 31.0, 31.0, 3.0, 3.7096774193548385, 0.0, 0.0, 2.0, 2.0, 15.5, 0.06, 0.763, 0.177, 0.5211], review_time:1357862400, review_score:5.0}]->(b);
#
# Executing query 61: MERGE (a:User {id: ' A2AXW2BKFCUI4', profile_name:' C. Baker CB'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' C. Baker CB', feature: [310.0, 250.0, 0.7709677419354839, 0.0, 0.04838709677419355, 0.1935483870967742, 0.035483870967741936, 72.0, 72.0, 4.0, 3.486111111111111, 0.0, 0.0, 7.0, 3.0, 10.285714285714286, 0.0, 0.683, 0.317, 0.967], review_time:1357603200, review_score:5.0}]->(b);
#
# Executing query 62: MERGE (a:User {id: ' AVM9Q84DHSJ5', profile_name:' Miles W. Gray'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Miles W. Gray', feature: [113.0, 92.0, 0.7964601769911505, 0.0, 0.017699115044247787, 0.18584070796460178, 0.017699115044247787, 24.0, 24.0, 1.0, 3.875, 0.0, 0.0, 2.0, 1.0, 12.0, 0.0, 0.595, 0.405, 0.8908], review_time:1357516800, review_score:5.0}]->(b);
#
# Executing query 63: MERGE (a:User {id: ' A3BRQ1TNK9V2SJ', profile_name:' Y. Hempstead'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Y. Hempstead', feature: [170.0, 136.0, 0.7823529411764706, 0.0, 0.01764705882352941, 0.2, 0.01764705882352941, 39.0, 39.0, 1.0, 3.5128205128205128, 0.0, 0.0, 2.0, 2.0, 19.5, 0.06, 0.734, 0.206, 0.7867], review_time:1357430400, review_score:5.0}]->(b);
#
# Executing query 64: MERGE (a:User {id: ' A1KIA8UKDG7JAJ', profile_name:' Richard Culp Robinson'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Richard Culp Robinson', feature: [134.0, 109.0, 0.7761194029850746, 0.0, 0.022388059701492536, 0.1865671641791045, 0.03731343283582089, 31.0, 31.0, 2.0, 3.5483870967741935, 0.0, 0.0, 2.0, 2.0, 15.5, 0.0, 0.906, 0.094, 0.358], review_time:1355443200, review_score:5.0}]->(b);
#
# Executing query 65: MERGE (a:User {id: ' A143K7IJD77AWW', profile_name:' Ahmed Franklin'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Ahmed Franklin', feature: [205.0, 169.0, 0.7951219512195122, 0.0, 0.02926829268292683, 0.17560975609756097, 0.02926829268292683, 43.0, 43.0, 4.0, 3.953488372093023, 0.0, 0.0, 4.0, 2.0, 10.75, 0.0, 0.633, 0.367, 0.9453], review_time:1355011200, review_score:5.0}]->(b);
#
# Executing query 66: MERGE (a:User {id: ' A4V05J66AYVYA', profile_name:' waldo castro'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' waldo castro', feature: [364.0, 305.0, 0.7802197802197802, 0.008241758241758242, 0.03021978021978022, 0.1620879120879121, 0.04945054945054945, 87.0, 87.0, 10.0, 3.5172413793103448, 0.0, 0.0, 9.0, 4.0, 9.666666666666666, 0.0, 0.896, 0.104, 0.6039], review_time:1354752000, review_score:5.0}]->(b);
#
# Executing query 67: MERGE (a:User {id: ' A26RUQZKJYLYA1', profile_name:' J. Perkins'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' J. Perkins', feature: [428.0, 355.0, 0.7990654205607477, 0.0, 0.02336448598130841, 0.1705607476635514, 0.030373831775700934, 89.0, 89.0, 13.0, 4.0, 0.0, 0.0, 6.0, 4.0, 14.833333333333334, 0.0, 0.682, 0.318, 0.9788], review_time:1357344000, review_score:5.0}]->(b);
#
# Executing query 68: MERGE (a:User {id: ' AK5J1LLTPLNFS', profile_name:' Jeffrey J. Flegler'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Jeffrey J. Flegler', feature: [170.0, 141.0, 0.7941176470588235, 0.0, 0.041176470588235294, 0.17058823529411765, 0.03529411764705882, 36.0, 36.0, 6.0, 3.9444444444444446, 0.0, 0.0, 6.0, 2.0, 6.0, 0.0, 0.538, 0.462, 0.9633], review_time:1357344000, review_score:5.0}]->(b);
#
# Executing query 69: MERGE (a:User {id: ' AO0I4ACUAXDQA', profile_name:' GhostXXX'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' GhostXXX', feature: [190.0, 151.0, 0.7368421052631579, 0.0, 0.04736842105263158, 0.20526315789473684, 0.05789473684210526, 49.0, 49.0, 2.0, 3.1020408163265305, 0.0, 0.0, 2.0, 1.0, 24.5, 0.165, 0.61, 0.226, 0.5856], review_time:1357257600, review_score:5.0}]->(b);
#
# Executing query 70: MERGE (a:User {id: ' A2SDQ26Q5RRFD', profile_name:' Dad72'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Dad72', feature: [365.0, 300.0, 0.8, 0.0, 0.01643835616438356, 0.1780821917808219, 0.021917808219178082, 74.0, 74.0, 9.0, 4.0675675675675675, 0.0, 0.0, 6.0, 3.0, 12.333333333333334, 0.041, 0.57, 0.389, 0.987], review_time:1356998400, review_score:5.0}]->(b);
#
# Executing query 71: MERGE (a:User {id: ' AOYER14P89ZHK', profile_name:' Christopher Mohme'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Christopher Mohme', feature: [133.0, 112.0, 0.8045112781954887, 0.0, 0.015037593984962405, 0.15789473684210525, 0.03759398496240601, 27.0, 27.0, 3.0, 4.185185185185185, 0.0, 0.0, 2.0, 1.0, 13.5, 0.0, 0.608, 0.392, 0.9118], review_time:1356825600, review_score:5.0}]->(b);
#
# Executing query 72: MERGE (a:User {id: ' A3FIUJ932PAFHL', profile_name:' Ron'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Ron', feature: [115.0, 95.0, 0.7913043478260869, 0.0, 0.034782608695652174, 0.17391304347826086, 0.034782608695652174, 25.0, 25.0, 4.0, 3.84, 0.0, 0.0, 4.0, 1.0, 6.25, 0.0, 0.672, 0.328, 0.8519], review_time:1356825600, review_score:5.0}]->(b);
#
# Executing query 73: MERGE (a:User {id: ' AOBHFGHGMTMQL', profile_name:' Philthy Philthy'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Philthy Philthy', feature: [206.0, 167.0, 0.7718446601941747, 0.014563106796116505, 0.014563106796116505, 0.18932038834951456, 0.024271844660194174, 45.0, 45.0, 2.0, 3.7333333333333334, 0.0, 0.0, 3.0, 2.0, 15.0, 0.0, 0.686, 0.314, 0.9335], review_time:1354579200, review_score:5.0}]->(b);
#
# Executing query 74: MERGE (a:User {id: ' A28C6IR06V7X9M', profile_name:' RetiredBio'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' RetiredBio', feature: [718.0, 584.0, 0.7743732590529248, 0.013927576601671309, 0.027855153203342618, 0.18662952646239556, 0.025069637883008356, 156.0, 156.0, 20.0, 3.75, 0.0, 0.0, 8.0, 7.0, 19.5, 0.023, 0.809, 0.167, 0.9473], review_time:1353974400, review_score:5.0}]->(b);
#
# Executing query 75: MERGE (a:User {id: ' A2IZ2GWDCACQTF', profile_name:' DGiff'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' DGiff', feature: [341.0, 284.0, 0.7712609970674487, 0.011730205278592375, 0.04105571847507331, 0.16715542521994134, 0.04985337243401759, 72.0, 72.0, 11.0, 3.9583333333333335, 0.0, 0.0, 9.0, 3.0, 8.0, 0.07, 0.667, 0.263, 0.9308], review_time:1353888000, review_score:5.0}]->(b);
#
# Executing query 76: MERGE (a:User {id: ' A3KUBL9O3BXCVT', profile_name:' charles stoddard'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' charles stoddard', feature: [222.0, 182.0, 0.7792792792792793, 0.0045045045045045045, 0.02252252252252252, 0.18018018018018017, 0.036036036036036036, 52.0, 52.0, 5.0, 3.519230769230769, 0.0, 0.0, 3.0, 3.0, 17.333333333333332, 0.0, 0.854, 0.146, 0.7574], review_time:1353801600, review_score:5.0}]->(b);
#
# Executing query 77: MERGE (a:User {id: ' A33IBGHYLRK0Z9', profile_name:' Old Man'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Old Man', feature: [303.0, 241.0, 0.7722772277227723, 0.006600660066006601, 0.056105610561056105, 0.20462046204620463, 0.0165016501650165, 70.0, 70.0, 3.0, 3.4571428571428573, 0.0, 0.0, 5.0, 4.0, 14.0, 0.109, 0.635, 0.257, 0.9287], review_time:1353628800, review_score:5.0}]->(b);
#
# Executing query 78: MERGE (a:User {id: ' A1UHCJ5YE0ZPHN', profile_name:' Plumber'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Plumber', feature: [228.0, 188.0, 0.7543859649122807, 0.0, 0.02631578947368421, 0.17543859649122806, 0.07017543859649122, 53.0, 53.0, 5.0, 3.5660377358490565, 0.0, 0.0, 5.0, 2.0, 10.6, 0.052, 0.822, 0.127, 0.4939], review_time:1353628800, review_score:5.0}]->(b);
#
# Executing query 79: MERGE (a:User {id: ' ABJTKK8B91ACO', profile_name:' Pileous Bolox'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Pileous Bolox', feature: [805.0, 660.0, 0.7913043478260869, 0.002484472049689441, 0.014906832298136646, 0.18012422360248448, 0.02608695652173913, 167.0, 167.0, 19.0, 3.9580838323353293, 0.0, 0.0, 7.0, 7.0, 23.857142857142858, 0.048, 0.829, 0.124, 0.8714], review_time:1343174400, review_score:5.0}]->(b);
#
# Executing query 80: MERGE (a:User {id: ' A1B1ZOVL67OXVP', profile_name:' Chacham'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Chacham', feature: [126.0, 101.0, 0.7698412698412699, 0.0, 0.023809523809523808, 0.1984126984126984, 0.031746031746031744, 30.0, 30.0, 5.0, 3.4, 0.0, 0.0, 3.0, 1.0, 10.0, 0.0, 0.579, 0.421, 0.92], review_time:1342137600, review_score:5.0}]->(b);
#
# Executing query 81: MERGE (a:User {id: ' A2XBCSGPGFFD3N', profile_name:' vinyldavid vinyldavid'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' vinyldavid vinyldavid', feature: [614.0, 494.0, 0.757328990228013, 0.009771986970684038, 0.03420195439739414, 0.19543973941368079, 0.03745928338762215, 146.0, 146.0, 14.0, 3.3904109589041096, 0.0, 0.0, 6.0, 6.0, 24.333333333333332, 0.038, 0.859, 0.103, 0.796], review_time:1341100800, review_score:5.0}]->(b);
#
# Executing query 82: MERGE (a:User {id: ' AKHSZLEPUTTY', profile_name:' sprague55'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' sprague55', feature: [212.0, 173.0, 0.7830188679245284, 0.0, 0.03773584905660377, 0.18396226415094338, 0.0330188679245283, 46.0, 46.0, 7.0, 3.782608695652174, 0.0, 0.0, 3.0, 2.0, 15.333333333333334, 0.0, 0.783, 0.217, 0.8342], review_time:1340755200, review_score:5.0}]->(b);
#
# Executing query 83: MERGE (a:User {id: ' A1KDYISB3PMNYD', profile_name:' Eric Tompkins'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Eric Tompkins', feature: [1150.0, 944.0, 0.7991304347826087, 0.0034782608695652175, 0.013043478260869565, 0.1791304347826087, 0.018260869565217393, 231.0, 231.0, 38.0, 4.090909090909091, 0.0, 0.0, 8.0, 8.0, 28.875, 0.06, 0.777, 0.162, 0.9726], review_time:1339545600, review_score:5.0}]->(b);
#
# Executing query 84: MERGE (a:User {id: ' A1YYH1I0F96NJ9', profile_name:' Hoping To Help'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Hoping To Help', feature: [869.0, 715.0, 0.7848101265822784, 0.0, 0.02761795166858458, 0.17721518987341772, 0.0379746835443038, 184.0, 184.0, 30.0, 3.891304347826087, 0.0, 0.0, 8.0, 7.0, 23.0, 0.008, 0.78, 0.212, 0.9848], review_time:1334707200, review_score:5.0}]->(b);
#
# Executing query 85: MERGE (a:User {id: ' A21S40CBGKKF4N', profile_name:' Paul'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Paul', feature: [1059.0, 858.0, 0.7780925401322002, 0.0056657223796034, 0.019830028328611898, 0.18980169971671387, 0.02644003777148253, 230.0, 230.0, 30.0, 3.734782608695652, 0.0, 0.0, 11.0, 11.0, 20.90909090909091, 0.056, 0.814, 0.13, 0.9554], review_time:1332288000, review_score:5.0}]->(b);
#
# Executing query 86: MERGE (a:User {id: ' A1DE1O0BC90P4X', profile_name:' Boddhisativa'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Boddhisativa', feature: [213.0, 177.0, 0.7981220657276995, 0.0, 0.03755868544600939, 0.16901408450704225, 0.03286384976525822, 44.0, 44.0, 6.0, 4.045454545454546, 0.0, 0.0, 4.0, 2.0, 11.0, 0.0, 0.737, 0.263, 0.8658], review_time:1331683200, review_score:5.0}]->(b);
#
# Executing query 87: MERGE (a:User {id: ' AC7DHC5EVP9L0', profile_name:' Luis CR'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Luis CR', feature: [439.0, 371.0, 0.7881548974943052, 0.002277904328018223, 0.015945330296127564, 0.1548974943052392, 0.05466970387243736, 87.0, 87.0, 16.0, 4.275862068965517, 0.0, 0.0, 5.0, 4.0, 17.4, 0.032, 0.921, 0.046, 0.2444], review_time:1281484800, review_score:5.0}]->(b);
#
# Executing query 88: MERGE (a:User {id: ' A3NNS7KZIIJ6D6', profile_name:' Tad Sargent'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Tad Sargent', feature: [475.0, 388.0, 0.783157894736842, 0.004210526315789474, 0.021052631578947368, 0.1831578947368421, 0.029473684210526315, 103.0, 103.0, 12.0, 3.7766990291262137, 0.0, 0.0, 6.0, 5.0, 17.166666666666668, 0.048, 0.789, 0.163, 0.8787], review_time:1322438400, review_score:5.0}]->(b);
#
# Executing query 89: MERGE (a:User {id: ' A1JPCNQQ3QKMCJ', profile_name:' bigk'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' bigk', feature: [121.0, 97.0, 0.7603305785123967, 0.03305785123966942, 0.0, 0.19834710743801653, 0.008264462809917356, 26.0, 26.0, 2.0, 3.769230769230769, 0.0, 0.0, 2.0, 1.0, 13.0, 0.053, 0.679, 0.268, 0.6908], review_time:1320883200, review_score:5.0}]->(b);
#
# Executing query 90: MERGE (a:User {id: ' A3A7BMMK0VKVDQ', profile_name:' Shuptyler'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Shuptyler', feature: [391.0, 316.0, 0.7595907928388747, 0.015345268542199489, 0.028132992327365727, 0.1918158567774936, 0.03324808184143223, 94.0, 94.0, 7.0, 3.372340425531915, 0.0, 0.0, 6.0, 5.0, 15.666666666666666, 0.026, 0.871, 0.103, 0.7941], review_time:1320796800, review_score:5.0}]->(b);
#
# Executing query 91: MERGE (a:User {id: ' A1IU7ZX30NFU2Z', profile_name:' Charles L. Williams'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Charles L. Williams', feature: [283.0, 229.0, 0.7773851590106007, 0.0035335689045936395, 0.014134275618374558, 0.19081272084805653, 0.028268551236749116, 63.0, 63.0, 6.0, 3.6507936507936507, 0.0, 0.0, 4.0, 3.0, 15.75, 0.0, 0.696, 0.304, 0.9509], review_time:1320364800, review_score:5.0}]->(b);
#
# Executing query 92: MERGE (a:User {id: ' A3DZX2UIRXRXJO', profile_name:' S. McCarthy'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' S. McCarthy', feature: [131.0, 108.0, 0.7709923664122137, 0.0, 0.030534351145038167, 0.17557251908396945, 0.05343511450381679, 32.0, 32.0, 1.0, 3.40625, 0.0, 0.0, 4.0, 1.0, 8.0, 0.0, 0.641, 0.359, 0.8779], review_time:1319068800, review_score:5.0}]->(b);
#
# Executing query 93: MERGE (a:User {id: ' A3RVV83XS80I5R', profile_name:' Stub'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Stub', feature: [346.0, 281.0, 0.7745664739884393, 0.005780346820809248, 0.023121387283236993, 0.18786127167630057, 0.031791907514450865, 75.0, 75.0, 7.0, 3.76, 0.0, 0.0, 4.0, 2.0, 18.75, 0.0, 0.797, 0.203, 0.9227], review_time:1289088000, review_score:5.0}]->(b);
#
# Executing query 94: MERGE (a:User {id: ' AE57OV94ZRTZH', profile_name:' mhilldj88'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' mhilldj88', feature: [150.0, 123.0, 0.7866666666666666, 0.006666666666666667, 0.04, 0.18, 0.02666666666666667, 32.0, 32.0, 4.0, 3.875, 0.0, 0.0, 4.0, 1.0, 8.0, 0.0, 0.639, 0.361, 0.8976], review_time:1288483200, review_score:5.0}]->(b);
#
# Executing query 95: MERGE (a:User {id: ' AYAM69300HRY4', profile_name:' D. Phillips'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' D. Phillips', feature: [176.0, 142.0, 0.7784090909090909, 0.0, 0.017045454545454544, 0.19318181818181818, 0.028409090909090908, 40.0, 40.0, 3.0, 3.575, 0.0, 0.0, 3.0, 1.0, 13.333333333333334, 0.0, 0.733, 0.267, 0.8805], review_time:1285718400, review_score:5.0}]->(b);
#
# Executing query 96: MERGE (a:User {id: ' A1WYX0BDPH6L9P', profile_name:' Book crazy'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Book crazy', feature: [98.0, 77.0, 0.7653061224489796, 0.0, 0.02040816326530612, 0.21428571428571427, 0.02040816326530612, 24.0, 24.0, 1.0, 3.25, 0.0, 0.0, 3.0, 1.0, 8.0, 0.0, 0.829, 0.171, 0.5719], review_time:1282262400, review_score:5.0}]->(b);
#
# Executing query 97: MERGE (a:User {id: ' A2GV26IXB73ZTY', profile_name:' A. Ashworth'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' A. Ashworth', feature: [192.0, 156.0, 0.7916666666666666, 0.0, 0.0, 0.1875, 0.020833333333333332, 40.0, 40.0, 5.0, 3.925, 0.0, 0.0, 2.0, 1.0, 20.0, 0.0, 0.731, 0.269, 0.8925], review_time:1281052800, review_score:5.0}]->(b);
#
# Executing query 98: MERGE (a:User {id: ' AXK2OFFY0QC0M', profile_name:' Joel'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Joel', feature: [128.0, 105.0, 0.7734375, 0.0234375, 0.0234375, 0.1796875, 0.0234375, 27.0, 27.0, 3.0, 3.925925925925926, 0.0, 0.0, 2.0, 1.0, 13.5, 0.08, 0.725, 0.196, 0.4939], review_time:1280275200, review_score:5.0}]->(b);
#
# Executing query 99: MERGE (a:User {id: ' unknown', profile_name:' unknown'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' unknown', feature: [353.0, 294.0, 0.8130311614730878, 0.0, 0.053824362606232294, 0.1671388101983003, 0.019830028328611898, 68.0, 68.0, 19.0, 4.338235294117647, 0.0, 0.0, 2.0, 2.0, 34.0, 0.113, 0.887, 0.0, -0.6808], review_time:1221955200, review_score:5.0}]->(b);
#
# Executing query 100: MERGE (a:User {id: ' A1WIPHHKQ6130C', profile_name:' bobbyo'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' bobbyo', feature: [422.0, 349.0, 0.7938388625592417, 0.0, 0.018957345971563982, 0.17298578199052134, 0.03317535545023697, 88.0, 88.0, 9.0, 3.977272727272727, 0.0, 0.0, 7.0, 5.0, 12.571428571428571, 0.0, 0.76, 0.24, 0.9578], review_time:1361318400, review_score:5.0}]->(b);
#
# Executing query 101: MERGE (a:User {id: ' A8JO0K7KML950', profile_name:' Stephen L. Pelfrey Jr.'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Stephen L. Pelfrey Jr.', feature: [210.0, 171.0, 0.7761904761904762, 0.009523809523809525, 0.01904761904761905, 0.18571428571428572, 0.02857142857142857, 45.0, 45.0, 4.0, 3.8222222222222224, 0.0, 0.0, 4.0, 2.0, 11.25, 0.0, 0.795, 0.205, 0.8176], review_time:1361145600, review_score:5.0}]->(b);
#
# Executing query 102: MERGE (a:User {id: ' A173DGY3YH0HS4', profile_name:' Anna Dunster'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Anna Dunster', feature: [1070.0, 870.0, 0.7831775700934579, 0.004672897196261682, 0.014018691588785047, 0.18691588785046728, 0.025233644859813085, 229.0, 229.0, 33.0, 3.8034934497816595, 0.0, 0.0, 8.0, 8.0, 28.625, 0.078, 0.819, 0.103, 0.6553], review_time:1360713600, review_score:5.0}]->(b);
#
# Executing query 103: MERGE (a:User {id: ' A1D2Q0Y30FQT50', profile_name:' David'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' David', feature: [298.0, 242.0, 0.7718120805369127, 0.006711409395973154, 0.030201342281879196, 0.18791946308724833, 0.03355704697986577, 68.0, 68.0, 5.0, 3.573529411764706, 0.0, 0.0, 5.0, 4.0, 13.6, 0.081, 0.813, 0.106, 0.128], review_time:1360368000, review_score:5.0}]->(b);
#
# Executing query 104: MERGE (a:User {id: ' A29MSABEQN8JTC', profile_name:' Cindy'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Cindy', feature: [220.0, 179.0, 0.7909090909090909, 0.0, 0.01818181818181818, 0.18636363636363637, 0.022727272727272728, 48.0, 48.0, 6.0, 3.75, 0.0, 0.0, 5.0, 2.0, 9.6, 0.0, 0.888, 0.112, 0.5994], review_time:1360281600, review_score:5.0}]->(b);
#
# Executing query 105: MERGE (a:User {id: ' A5916QY7BR5TU', profile_name:' Amazon Shopper'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Amazon Shopper', feature: [663.0, 534.0, 0.770739064856712, 0.0015082956259426848, 0.01809954751131222, 0.19457013574660634, 0.033182503770739065, 148.0, 148.0, 14.0, 3.614864864864865, 0.0, 0.0, 7.0, 5.0, 21.142857142857142, 0.062, 0.839, 0.099, 0.7809], review_time:1302393600, review_score:5.0}]->(b);
#
# Executing query 106: MERGE (a:User {id: ' A3UUJAUZ56CWFK', profile_name:' Van van johnson'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Van van johnson', feature: [540.0, 433.0, 0.7444444444444445, 0.025925925925925925, 0.027777777777777776, 0.19814814814814816, 0.03148148148148148, 130.0, 130.0, 8.0, 3.3384615384615386, 0.0, 0.0, 10.0, 7.0, 13.0, 0.038, 0.856, 0.106, 0.7529], review_time:1254528000, review_score:5.0}]->(b);
#
# Executing query 107: MERGE (a:User {id: ' A30WHKIW4A6ULB', profile_name:' ramblinman'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' ramblinman', feature: [243.0, 200.0, 0.8065843621399177, 0.0, 0.01646090534979424, 0.17695473251028807, 0.01646090534979424, 48.0, 48.0, 8.0, 4.1875, 0.0, 0.0, 3.0, 1.0, 16.0, 0.047, 0.74, 0.213, 0.8357], review_time:1360022400, review_score:5.0}]->(b);
#
# Executing query 108: MERGE (a:User {id: ' ASG68R3QB0MPM', profile_name:' BigTank7'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' BigTank7', feature: [166.0, 136.0, 0.7530120481927711, 0.012048192771084338, 0.03614457831325301, 0.18072289156626506, 0.05421686746987952, 40.0, 40.0, 3.0, 3.425, 0.0, 0.0, 4.0, 2.0, 10.0, 0.0, 1.0, 0.0, 0.0], review_time:1338940800, review_score:5.0}]->(b);
#
# Executing query 109: MERGE (a:User {id: ' A3K2FO5OOR9063', profile_name:' Lynn W. Larremore'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Lynn W. Larremore', feature: [449.0, 373.0, 0.779510022271715, 0.0066815144766146995, 0.031180400890868598, 0.16926503340757237, 0.044543429844097995, 99.0, 99.0, 15.0, 3.7777777777777777, 0.0, 0.0, 7.0, 5.0, 14.142857142857142, 0.052, 0.654, 0.293, 0.9559], review_time:1249344000, review_score:5.0}]->(b);
#
# Executing query 110: MERGE (a:User {id: ' A2K40RVHXMTA2A', profile_name:' Christopher D. Sutcliff Chris Sutcliff'}) MERGE (b:Item {id: ' B000A8OBO8'}) MERGE (a)-[:REVIEWED {review_text:' Christopher D. Sutcliff Chris Sutcliff', feature: [311.0, 253.0, 0.7942122186495176, 0.0, 0.022508038585209004, 0.1864951768488746, 0.01929260450160772, 66.0, 66.0, 9.0, 3.8484848484848486, 0.0, 0.0, 6.0, 4.0, 11.0, 0.111, 0.677, 0.212, 0.7713], review_time:1244419200, review_score:5.0}]->(b);
#
# ...
#
# Executing query 670: MERGE (a:User {id: ' AG2U4AT8OB4RD', profile_name:' TenGHz'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' TenGHz', feature: [340.0, 275.0, 0.7764705882352941, 0.0058823529411764705, 0.014705882352941176, 0.19117647058823528, 0.026470588235294117, 75.0, 75.0, 9.0, 3.68, 0.0, 0.0, 5.0, 3.0, 15.0, 0.0, 0.855, 0.145, 0.8655], review_time:1326326400, review_score:5.0}]->(b);
#
# Executing query 671: MERGE (a:User {id: ' A34L02F020M2R0', profile_name:' Lisa Mercer'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Lisa Mercer', feature: [163.0, 132.0, 0.7791411042944786, 0.0, 0.024539877300613498, 0.1901840490797546, 0.03067484662576687, 35.0, 35.0, 3.0, 3.8, 0.0, 0.0, 3.0, 3.0, 11.666666666666666, 0.0, 0.743, 0.257, 0.8658], review_time:1326240000, review_score:5.0}]->(b);
#
# Executing query 672: MERGE (a:User {id: ' AQ15FOQM41H2M', profile_name:' Herman Michaels'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Herman Michaels', feature: [589.0, 481.0, 0.7928692699490663, 0.0, 0.027164685908319185, 0.1833616298811545, 0.023769100169779286, 125.0, 125.0, 14.0, 3.856, 0.0, 0.0, 9.0, 5.0, 13.88888888888889, 0.057, 0.868, 0.075, 0.4399], review_time:1326067200, review_score:5.0}]->(b);
#
# Executing query 673: MERGE (a:User {id: ' A1YXXUGZFG3GRI', profile_name:' Dmandal'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Dmandal', feature: [724.0, 588.0, 0.7693370165745856, 0.016574585635359115, 0.023480662983425413, 0.1878453038674033, 0.026243093922651933, 152.0, 152.0, 20.0, 3.875, 0.0, 0.0, 12.0, 4.0, 12.666666666666666, 0.019, 0.823, 0.158, 0.9593], review_time:1325462400, review_score:5.0}]->(b);
#
# Executing query 674: MERGE (a:User {id: ' A1VNCPZRQH3A1D', profile_name:' Mona'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Mona', feature: [669.0, 538.0, 0.7847533632286996, 0.0, 0.017937219730941704, 0.19581464872944693, 0.01943198804185351, 144.0, 144.0, 16.0, 3.7430555555555554, 0.0, 0.0, 9.0, 6.0, 16.0, 0.036, 0.732, 0.231, 0.9741], review_time:1325376000, review_score:5.0}]->(b);
#
# Executing query 675: MERGE (a:User {id: ' A10HJYGG454D0C', profile_name:' LuNiZ99'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' LuNiZ99', feature: [134.0, 112.0, 0.8059701492537313, 0.0, 0.022388059701492536, 0.16417910447761194, 0.029850746268656716, 28.0, 28.0, 4.0, 4.035714285714286, 0.0, 0.0, 3.0, 2.0, 9.333333333333334, 0.0, 0.478, 0.522, 0.9552], review_time:1325376000, review_score:5.0}]->(b);
#
# Executing query 676: MERGE (a:User {id: ' A17X9BA2OBWTC', profile_name:' BikendHike'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' BikendHike', feature: [299.0, 245.0, 0.7926421404682275, 0.0033444816053511705, 0.020066889632107024, 0.1806020066889632, 0.023411371237458192, 62.0, 62.0, 8.0, 3.967741935483871, 0.0, 0.0, 4.0, 4.0, 15.5, 0.118, 0.738, 0.144, 0.3876], review_time:1325289600, review_score:5.0}]->(b);
#
# Executing query 677: MERGE (a:User {id: ' A3H98L5UVDPQM4', profile_name:' tracker'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' tracker', feature: [247.0, 199.0, 0.7773279352226721, 0.004048582995951417, 0.032388663967611336, 0.19433198380566802, 0.024291497975708502, 56.0, 56.0, 4.0, 3.5714285714285716, 0.0, 0.0, 5.0, 3.0, 11.2, 0.0, 0.826, 0.174, 0.7681], review_time:1325203200, review_score:5.0}]->(b);
#
# Executing query 678: MERGE (a:User {id: ' A8WFYCPRP8CIC', profile_name:' W. OMaley'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' W. OMaley', feature: [251.0, 205.0, 0.7928286852589641, 0.00796812749003984, 0.02390438247011952, 0.18326693227091634, 0.01593625498007968, 52.0, 52.0, 8.0, 3.9615384615384617, 0.0, 0.0, 3.0, 2.0, 17.333333333333332, 0.0, 0.751, 0.249, 0.9116], review_time:1265760000, review_score:5.0}]->(b);
#
# Executing query 679: MERGE (a:User {id: ' A1LCJXQQ33YW8H', profile_name:' Luini'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Luini', feature: [279.0, 227.0, 0.7849462365591398, 0.0035842293906810036, 0.021505376344086023, 0.1863799283154122, 0.025089605734767026, 60.0, 60.0, 7.0, 3.8, 0.0, 0.0, 5.0, 3.0, 12.0, 0.0, 0.736, 0.264, 0.9297], review_time:1264636800, review_score:5.0}]->(b);
#
# Executing query 680: MERGE (a:User {id: ' A1X3DNBXGBQ59M', profile_name:' baron von hofmann'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' baron von hofmann', feature: [913.0, 744.0, 0.7842278203723987, 0.01095290251916758, 0.014238773274917854, 0.1851040525739321, 0.019715224534501644, 189.0, 189.0, 24.0, 3.941798941798942, 0.0, 0.0, 8.0, 7.0, 23.625, 0.092, 0.766, 0.142, 0.9119], review_time:1263772800, review_score:5.0}]->(b);
#
# Executing query 681: MERGE (a:User {id: ' A71SWZGQ58XQE', profile_name:' G. Stokes His Works'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' G. Stokes His Works', feature: [363.0, 293.0, 0.7851239669421488, 0.0, 0.01652892561983471, 0.1928374655647383, 0.02203856749311295, 79.0, 79.0, 9.0, 3.721518987341772, 0.0, 0.0, 6.0, 5.0, 13.166666666666666, 0.0, 0.903, 0.097, 0.7713], review_time:1255651200, review_score:5.0}]->(b);
#
# Executing query 682: MERGE (a:User {id: ' A2WF1Y027G3TSO', profile_name:' AR AR'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' AR AR', feature: [278.0, 229.0, 0.7877697841726619, 0.0, 0.03597122302158273, 0.17625899280575538, 0.03597122302158273, 61.0, 61.0, 10.0, 3.7704918032786887, 0.0, 0.0, 5.0, 3.0, 12.2, 0.064, 0.69, 0.246, 0.8416], review_time:1255651200, review_score:5.0}]->(b);
#
# Executing query 683: MERGE (a:User {id: ' A2UYTLS46AT6OH', profile_name:' L. Salway'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' L. Salway', feature: [228.0, 190.0, 0.7763157894736842, 0.0043859649122807015, 0.043859649122807015, 0.16666666666666666, 0.05263157894736842, 50.0, 50.0, 7.0, 3.82, 0.0, 0.0, 5.0, 1.0, 10.0, 0.0, 0.804, 0.196, 0.8307], review_time:1255219200, review_score:5.0}]->(b);
#
# Executing query 684: MERGE (a:User {id: ' A2LM65P1UGFIPX', profile_name:' Larry D'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Larry D', feature: [382.0, 315.0, 0.7984293193717278, 0.0, 0.020942408376963352, 0.17539267015706805, 0.02617801047120419, 80.0, 80.0, 14.0, 3.95, 0.0, 0.0, 6.0, 4.0, 13.333333333333334, 0.0, 0.624, 0.376, 0.9878], review_time:1358812800, review_score:5.0}]->(b);
#
# Executing query 685: MERGE (a:User {id: ' A1AKHGRSV8JEAK', profile_name:' Barbara J Burden'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Barbara J Burden', feature: [131.0, 104.0, 0.7633587786259542, 0.0, 0.030534351145038167, 0.20610687022900764, 0.030534351145038167, 32.0, 32.0, 2.0, 3.28125, 0.0, 0.0, 4.0, 0.0, 8.0, 0.0, 0.854, 0.146, 0.6249], review_time:1358812800, review_score:5.0}]->(b);
#
# Executing query 686: MERGE (a:User {id: ' AMF16CD3VUH41', profile_name:' Joe'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Joe', feature: [386.0, 307.0, 0.7694300518134715, 0.0, 0.02849740932642487, 0.20466321243523317, 0.025906735751295335, 90.0, 90.0, 7.0, 3.422222222222222, 0.0, 0.0, 7.0, 4.0, 12.857142857142858, 0.049, 0.787, 0.164, 0.8834], review_time:1358467200, review_score:5.0}]->(b);
#
# Executing query 687: MERGE (a:User {id: ' ARTDVYDBARWVP', profile_name:' C. A. Lewis'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' C. A. Lewis', feature: [317.0, 260.0, 0.804416403785489, 0.0, 0.015772870662460567, 0.17981072555205047, 0.015772870662460567, 63.0, 63.0, 8.0, 4.142857142857143, 0.0, 0.0, 4.0, 3.0, 15.75, 0.0, 0.857, 0.143, 0.8], review_time:1358467200, review_score:5.0}]->(b);
#
# Executing query 688: MERGE (a:User {id: ' A2PR2IUAC2JPGE', profile_name:' amanda harris'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' amanda harris', feature: [175.0, 146.0, 0.8114285714285714, 0.0, 0.022857142857142857, 0.1657142857142857, 0.022857142857142857, 35.0, 35.0, 5.0, 4.2, 0.0, 0.0, 4.0, 1.0, 8.75, 0.093, 0.687, 0.219, 0.556], review_time:1358208000, review_score:5.0}]->(b);
#
# Executing query 689: MERGE (a:User {id: ' A2FSCJF0QZECHR', profile_name:' LT Sci Fi fan'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' LT Sci Fi fan', feature: [2378.0, 1918.0, 0.7750210260723297, 0.004625735912531539, 0.027754415475189236, 0.1934398654331371, 0.02691337258200168, 524.0, 524.0, 55.0, 3.6622137404580153, 0.0, 0.0, 26.0, 22.0, 20.153846153846153, 0.055, 0.83, 0.115, 0.9842], review_time:1224892800, review_score:5.0}]->(b);
#
# Executing query 690: MERGE (a:User {id: ' A1VU65PBC07NCL', profile_name:' Ric Hap'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Ric Hap', feature: [310.0, 246.0, 0.7677419354838709, 0.0, 0.012903225806451613, 0.2064516129032258, 0.025806451612903226, 71.0, 71.0, 4.0, 3.4788732394366195, 0.0, 0.0, 5.0, 3.0, 14.2, 0.113, 0.741, 0.146, 0.6501], review_time:1200009600, review_score:5.0}]->(b);
#
# Executing query 691: MERGE (a:User {id: ' A3OS8JKPTLRWZE', profile_name:' Susan Kraemer sci fi geek'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Susan Kraemer sci fi geek', feature: [1232.0, 981.0, 0.7678571428571429, 0.0, 0.03977272727272727, 0.20373376623376624, 0.028409090909090908, 289.0, 289.0, 17.0, 3.397923875432526, 0.0, 0.0, 15.0, 15.0, 19.266666666666666, 0.04, 0.841, 0.119, 0.9723], review_time:1295222400, review_score:5.0}]->(b);
#
# Executing query 692: MERGE (a:User {id: ' A27P9BMJ3NNQ4S', profile_name:' J. Preston JDP'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' J. Preston JDP', feature: [1302.0, 1056.0, 0.7803379416282642, 0.0069124423963133645, 0.01152073732718894, 0.1889400921658986, 0.023809523809523808, 280.0, 280.0, 33.0, 3.775, 0.0, 0.0, 11.0, 10.0, 25.454545454545453, 0.083, 0.815, 0.103, 0.5122], review_time:1286409600, review_score:5.0}]->(b);
#
# Executing query 693: MERGE (a:User {id: ' A1UJYCTUIUOL13', profile_name:' carplips'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' carplips', feature: [434.0, 367.0, 0.8179723502304147, 0.004608294930875576, 0.020737327188940093, 0.1543778801843318, 0.02304147465437788, 81.0, 81.0, 18.0, 4.54320987654321, 0.0, 0.0, 6.0, 5.0, 13.5, 0.056, 0.726, 0.218, 0.9284], review_time:1306800000, review_score:5.0}]->(b);
#
# Executing query 694: MERGE (a:User {id: ' A2CECLRFH55F8H', profile_name:' D'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' D', feature: [211.0, 172.0, 0.7819905213270142, 0.0, 0.023696682464454975, 0.1848341232227488, 0.03317535545023697, 47.0, 47.0, 4.0, 3.6808510638297873, 0.0, 0.0, 5.0, 2.0, 9.4, 0.0, 0.691, 0.309, 0.9293], review_time:1305244800, review_score:5.0}]->(b);
#
# Executing query 695: MERGE (a:User {id: ' AP96SQ4ITIMGA', profile_name:' imneil'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' imneil', feature: [329.0, 267.0, 0.7933130699088146, 0.0, 0.02127659574468085, 0.1884498480243161, 0.0182370820668693, 69.0, 69.0, 7.0, 3.8840579710144927, 0.0, 0.0, 6.0, 3.0, 11.5, 0.0, 0.692, 0.308, 0.9694], review_time:1304380800, review_score:5.0}]->(b);
#
# Executing query 696: MERGE (a:User {id: ' AA9TKM0IIE2AM', profile_name:' Relationship Researcher'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Relationship Researcher', feature: [521.0, 428.0, 0.7946257197696737, 0.0, 0.026871401151631478, 0.1785028790786948, 0.026871401151631478, 110.0, 110.0, 18.0, 3.9, 0.0, 0.0, 6.0, 4.0, 18.333333333333332, 0.071, 0.775, 0.155, 0.8653], review_time:1295568000, review_score:5.0}]->(b);
#
# Executing query 697: MERGE (a:User {id: ' A2Y1QA8FM6LW5K', profile_name:' Jerry R Pressley'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Jerry R Pressley', feature: [519.0, 424.0, 0.7745664739884393, 0.0019267822736030828, 0.03468208092485549, 0.18304431599229287, 0.04046242774566474, 117.0, 117.0, 16.0, 3.6324786324786325, 0.0, 0.0, 6.0, 4.0, 19.5, 0.073, 0.799, 0.127, 0.8059], review_time:1289952000, review_score:5.0}]->(b);
#
# Executing query 698: MERGE (a:User {id: ' A1LX6Z0FMS7Q2M', profile_name:' William W. Crane'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' William W. Crane', feature: [915.0, 732.0, 0.7595628415300546, 0.0, 0.02185792349726776, 0.2, 0.040437158469945354, 221.0, 221.0, 19.0, 3.316742081447964, 0.0, 0.0, 13.0, 9.0, 17.0, 0.077, 0.82, 0.103, 0.6209], review_time:1268611200, review_score:5.0}]->(b);
#
# Executing query 699: MERGE (a:User {id: ' A2J84PE4QRF1VB', profile_name:' Avid hiker ct'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Avid hiker ct', feature: [180.0, 144.0, 0.7722222222222223, 0.005555555555555556, 0.03888888888888889, 0.2, 0.022222222222222223, 41.0, 41.0, 3.0, 3.5365853658536586, 0.0, 0.0, 5.0, 2.0, 8.2, 0.0, 0.649, 0.351, 0.9493], review_time:1350777600, review_score:5.0}]->(b);
#
# Executing query 700: MERGE (a:User {id: ' A3FL64R0BJTBLL', profile_name:' C. Lepucki'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' C. Lepucki', feature: [500.0, 397.0, 0.77, 0.002, 0.02, 0.206, 0.022, 115.0, 115.0, 8.0, 3.4608695652173913, 0.0, 0.0, 6.0, 5.0, 19.166666666666668, 0.03, 0.887, 0.084, 0.6369], review_time:1350604800, review_score:5.0}]->(b);
#
# Executing query 701: MERGE (a:User {id: ' AZ8H6F3EKWKKG', profile_name:' RUDI'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' RUDI', feature: [222.0, 185.0, 0.8063063063063063, 0.0, 0.02702702702702703, 0.16666666666666666, 0.02702702702702703, 44.0, 44.0, 9.0, 4.2272727272727275, 0.0, 0.0, 4.0, 2.0, 11.0, 0.047, 0.706, 0.247, 0.8438], review_time:1349654400, review_score:5.0}]->(b);
#
# Executing query 702: MERGE (a:User {id: ' A37WQ4XB4COBH7', profile_name:' Bill Brady'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Bill Brady', feature: [142.0, 116.0, 0.7887323943661971, 0.0, 0.028169014084507043, 0.18309859154929578, 0.028169014084507043, 31.0, 31.0, 6.0, 3.774193548387097, 0.0, 0.0, 3.0, 2.0, 10.333333333333334, 0.0, 0.65, 0.35, 0.883], review_time:1349568000, review_score:5.0}]->(b);
#
# Executing query 703: MERGE (a:User {id: ' A1BKBOMMLMK8JQ', profile_name:' mjbruns'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' mjbruns', feature: [202.0, 164.0, 0.7821782178217822, 0.0049504950495049506, 0.01485148514851485, 0.18811881188118812, 0.024752475247524754, 45.0, 45.0, 2.0, 3.6666666666666665, 0.0, 0.0, 2.0, 2.0, 22.5, 0.0, 0.844, 0.156, 0.7269], review_time:1356307200, review_score:5.0}]->(b);
#
# Executing query 704: MERGE (a:User {id: ' A3FOAYHWCUW15N', profile_name:' Steve Berry'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' Steve Berry', feature: [224.0, 182.0, 0.7723214285714286, 0.0, 0.04017857142857143, 0.1875, 0.04017857142857143, 53.0, 53.0, 1.0, 3.452830188679245, 0.0, 0.0, 6.0, 1.0, 8.833333333333334, 0.04, 0.726, 0.234, 0.8542], review_time:1355875200, review_score:5.0}]->(b);
#
# Executing query 705: MERGE (a:User {id: ' A2CACCYUSYQXJ8', profile_name:' RayB'}) MERGE (b:Item {id: ' B000A8OBQQ'}) MERGE (a)-[:REVIEWED {review_text:' RayB', feature: [1531.0, 1264.0, 0.7772697583278902, 0.008491182233834096, 0.039190071848465055, 0.1743958197256695, 0.039843239712606136, 326.0, 326.0, 48.0, 3.8803680981595092, 0.0, 0.0, 22.0, 12.0, 14.818181818181818, 0.052, 0.79, 0.157, 0.9842], review_time:1355788800, review_score:5.0}]->(b);

# %% [markdown]
# Now we need to change **TGN** mode to **eval** and start importing our **evaluation** queries.

# %%
results = memgraph.execute_and_fetch("CALL tgn.set_eval() YIELD *;")
for result in results:
    print(result)

for query in eval_queries:
    results = memgraph.execute_and_fetch(query.strip())
    for result in results:
        continue
# Out:
# {'message': "TGN mode changed to 'eval'."}

# %% [markdown]
# After our **stream** is done, we should probably do a few more rounds of training and evaluation in order to have the model working properly. We can do so with the following query:

# %%
num_of_epochs = 10

results = memgraph.execute_and_fetch(
    f"""
    CALL tgn.train_and_eval({num_of_epochs}) YIELD *
    RETURN epoch_num, batch_num, precision, batch_process_time, batch_type ORDER BY epoch_num, batch_num;
    """
)

for result in results:
    continue

# %% [markdown]
# Now, let's get the results and then do some **plotting** to check whether **precision** increases between epochs.

# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np

results_train_dict = defaultdict(list)  
results_eval_dict = defaultdict(list)

results = memgraph.execute_and_fetch(
    """
        CALL tgn.get_results() YIELD  epoch_num, batch_num, precision, batch_process_time, batch_type
        RETURN epoch_num, batch_num, precision, batch_process_time, batch_type ORDER BY epoch_num, batch_num;
    """
)

for result in results:
    if result['batch_type'] == 'Train':
        results_train_dict[result['epoch_num']].append(result['precision'])
    else:
        results_eval_dict[result['epoch_num']].append(result['precision'])

# %% [markdown]
# Now when we have collected the results, let's first plot the average `accuracy` of `train` batches inside epoch, and the average `accuracy` of `eval` batches inside epoch. We can do that since every batch is the same size. (**NB**: `TGN` uses a predefined batch size.)

# %%
X_train = []
Y_train = []

for epoch, batches_precision in results_train_dict.items():
    Y_train.append(np.mean(batches_precision))
    X_train.append(epoch)

X_eval = []
Y_eval = []
for epoch, batches_precision in results_eval_dict.items():
    Y_eval.append(np.mean(batches_precision))
    X_eval.append(epoch)


#scatter plot
plt.plot(X_train, Y_train, 'b', label="train")
plt.plot(X_eval, Y_eval, 'r', label="eval")

#add title
plt.title('epoch - average batch precision')

#add x and y labels
plt.xlabel('epoch')
plt.ylabel('precision')
plt.legend(loc="upper left")

#show plot
plt.show()

# %%
test = memgraph.execute_and_fetch(
    """
    MERGE (a:User {id: 'A1BHUGKLYW6H7V', profile_name:'P. Lecuyer'})
    MERGE (b:Item {id: 'B0007MCVQ2'})
    MERGE (a)-[:REVIEWED {review_text:'Like all Clarks, these guys didnt disappoint. They fit great and look even better. For the price, I dont think a better deal exists out there for casual shoes.',
    feature: [161.0, 133.0, 0.782608695652174, 0.0, 0.031055900621118012, 0.17391304347826086, 0.043478260869565216, 36.0, 36.0, 1.0, 3.6944444444444446, 0.0, 0.0, 3.0, 1.0, 12.0, 0.055, 0.519, 0.427, 0.9238],
    review_time:1127088000, review_score:5.0}]->(b);
    """
)

for result in test:
    print(result)

# %% [markdown]
# We can see that **average accuracy** increases, which is really good. Now we can start doing some recommending. Let's find `Users` who reviewed one `Item` positively and those who reviewed multiple `Items` positively. Our module will return what it believes should be a prediction score for yet unreviewed `Items`.

# %%
results = memgraph.execute_and_fetch(
    """
        MATCH (n:User)
        WITH n
        LIMIT 1
        MATCH (m:Item)
        OPTIONAL MATCH (n)-[r]->(m)
        WHERE r is null
        CALL tgn.predict_link_score(n,m) YIELD prediction
        WITH n,m, prediction
        WHERE prediction>0.5
        MERGE (n)-[:PREDICTED_REVIEW {likelihood:prediction}]->(m);
    """
)
for result in results:
    print(result)

# %% [markdown]
# Now we can make the following query in Memgraph Lab:
# ```cypher
# MATCH (u:User)-[pr:PREDICTED_REVIEW]->(i:Item), (u)-[r:REVIEWED]->(oi:Item)
# RETURN *;
# ```
#
# And after applying the style, we get our predicted edges visualized:
# ```
#
#
# @NodeStyle {
#   size: 6
#   color: #DD2222
#   color-hover: Lighter(#DD2222)
#   color-selected: Lighter(#DD2222)
#   border-width: 0.6
#   border-color: #1d1d1d
#
# }
#
# @NodeStyle HasLabel?(node, "User") {
#   color: #DD2222
#   color-hover: Lighter(#DD2222)
#   color-selected: Lighter(#DD2222)
#
# }
#
# @NodeStyle And(HasLabel?(node, "Item"), HasProperty?(node, "rank")) {
#   color: #720096
#   color-hover: Lighter(#720096)
#   color-selected: Lighter(#720096)
#   size: Mul(Property(node, "rank"), 200)
# }
#
#
# @NodeStyle HasLabel?(node, "Item") {
#   label: Format("{label}: {id}", Join(Labels(node), ", "), AsText(Property(node, "id")))
#   font-size: 10
# }
#
# @NodeStyle HasLabel?(node, "User") {
#   label: AsText(Property(node, "id"))
#   font-size: 2
# }
#
#
# @EdgeStyle {
#   color: #999999
#   color-hover: #1d1d1d
#   color-selected: #1d1d1d
#   width: 0.3
#   width-hover: 0.9
#   width-selected: 0.9
#   font-size: 3
# }
# @EdgeStyle HasProperty?(edge,"likelihood"){
#   color: #720096
#   color-hover: #720096
#   color-selected: #720096
#   width: Property(edge,"likelihood")
#   width-hover: 0.9
#   width-selected: 0.9
#   font-size: 3
# }
#
#
# ```
